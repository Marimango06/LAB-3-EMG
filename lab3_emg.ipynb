# %% [markdown]
# <a href="https://colab.research.google.com/github/Marimango06/LABORATORIO3-EMG/blob/main/lab3_emg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LABORATORIO 3 EMG

# %%
# !pip install scipy
# !pip install matplotlib
# !pip install numpy
# !pip install google.drive
# !pip install wfdb
# !pip install pandas
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting google.drive
#   Downloading google_drive-0.5.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting google-api-core==1.31.5 (from google.drive)
#   Downloading google_api_core-1.31.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting google-api-python-client==2.6.0 (from google.drive)
#   Downloading google_api_python_client-2.6.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting google-auth==1.35.0 (from google.drive)
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting google-auth-httplib2==0.1.0 (from google.drive)
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting google-auth-oauthlib==0.4.1 (from google.drive)
#   Downloading google_auth_oauthlib-0.4.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting googleapis-common-protos==1.56.0 (from google.drive)
#   Downloading googleapis_common_protos-1.56.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting dataclasses==0.6 (from google.drive)
#   Downloading dataclasses-0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: click==8.1.7 in /usr/local/lib/python3.10/dist-packages (from google.drive) (8.1.7)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core==1.31.5->google.drive) (2.32.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core==1.31.5->google.drive) (71.0.4)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core==1.31.5->google.drive) (24.1)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core==1.31.5->google.drive) (1.16.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from google-api-core==1.31.5->google.drive) (2024.2)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core==1.31.5->google.drive) (3.20.3)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==2.6.0->google.drive) (0.22.0)
# Collecting uritemplate<4dev,>=3.0.0 (from google-api-python-client==2.6.0->google.drive)
#   Downloading uritemplate-3.0.1-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth==1.35.0->google.drive)
#   Downloading cachetools-4.2.4-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth==1.35.0->google.drive) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth==1.35.0->google.drive) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib==0.4.1->google.drive) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client==2.6.0->google.drive) (3.1.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth==1.35.0->google.drive) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core==1.31.5->google.drive) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core==1.31.5->google.drive) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core==1.31.5->google.drive) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core==1.31.5->google.drive) (2024.8.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib==0.4.1->google.drive) (3.2.2)
# Downloading google_drive-0.5.1-py3-none-any.whl (15 kB)
# Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Downloading google_api_core-1.31.5-py2.py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 3.8 MB/s eta 0:00:00
# Downloading google_api_python_client-2.6.0-py2.py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 59.7 MB/s eta 0:00:00
# Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 11.1 MB/s eta 0:00:00
# Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Downloading google_auth_oauthlib-0.4.1-py2.py3-none-any.whl (18 kB)
# Downloading googleapis_common_protos-1.56.0-py2.py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 kB 16.3 MB/s eta 0:00:00
# Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Downloading uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Installing collected packages: dataclasses, uritemplate, googleapis-common-protos, cachetools, google-auth, google-auth-oauthlib, google-auth-httplib2, google-api-core, google-api-python-client, google.drive
#   Attempting uninstall: uritemplate
#     Found existing installation: uritemplate 4.1.1
#     Uninstalling uritemplate-4.1.1:
#       Successfully uninstalled uritemplate-4.1.1
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.65.0
#     Uninstalling googleapis-common-protos-1.65.0:
#       Successfully uninstalled googleapis-common-protos-1.65.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.5.0
#     Uninstalling cachetools-5.5.0:
#       Successfully uninstalled cachetools-5.5.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.27.0
#     Uninstalling google-auth-2.27.0:
#       Successfully uninstalled google-auth-2.27.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: google-auth-httplib2
#     Found existing installation: google-auth-httplib2 0.2.0
#     Uninstalling google-auth-httplib2-0.2.0:
#       Successfully uninstalled google-auth-httplib2-0.2.0
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.19.2
#     Uninstalling google-api-core-2.19.2:
#       Successfully uninstalled google-api-core-2.19.2
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.137.0
#     Uninstalling google-api-python-client-2.137.0:
#       Successfully uninstalled google-api-python-client-2.137.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.19.0 requires google-auth<3.0dev,>=2.15.0, but you have google-auth 1.35.0 which is incompatible.
# google-ai-generativelanguage 0.6.6 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-ai-generativelanguage 0.6.6 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-aiplatform 1.68.0 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-aiplatform 1.68.0 requires google-auth<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-bigquery 3.25.0 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-bigquery 3.25.0 requires google-auth<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-bigquery-connection 1.15.5 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-bigquery-connection 1.15.5 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-bigquery-storage 2.26.0 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-bigquery-storage 2.26.0 requires google-auth<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-bigtable 2.26.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-bigtable 2.26.0 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-core 2.4.1 requires google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-datastore 2.19.0 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-firestore 2.16.1 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-firestore 2.16.1 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-functions 1.16.5 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-functions 1.16.5 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-iam 2.15.2 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-iam 2.15.2 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-language 2.13.4 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-language 2.13.4 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-pubsub 2.25.1 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-pubsub 2.25.1 requires google-auth<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-resource-manager 1.12.5 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-resource-manager 1.12.5 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-translate 3.15.5 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1, but you have google-api-core 1.31.5 which is incompatible.
# google-cloud-translate 3.15.5 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.27.0, but you have google-auth 1.35.0 which is incompatible.
# google-generativeai 0.7.2 requires google-auth>=2.15.0, but you have google-auth 1.35.0 which is incompatible.
# pandas-gbq 0.23.2 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.31.5 which is incompatible.
# pandas-gbq 0.23.2 requires google-auth>=2.13.0, but you have google-auth 1.35.0 which is incompatible.
# pandas-gbq 0.23.2 requires google-auth-oauthlib>=0.7.0, but you have google-auth-oauthlib 0.4.1 which is incompatible.
# Successfully installed cachetools-4.2.4 dataclasses-0.6 google-api-core-1.31.5 google-api-python-client-2.6.0 google-auth-1.35.0 google-auth-httplib2-0.1.0 google-auth-oauthlib-0.4.1 google.drive-0.5.1 googleapis-common-protos-1.56.0 uritemplate-3.0.1
# Collecting wfdb
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.2.2)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.32.3)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2024.8.30)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import scipy.signal as signal
from scipy import stats
import google.colab as drive
import wfdb
import pandas as pd
import scipy.fftpack as fourier

# %%
#aplicacion del filtro pasa banda
## diseño del filtro
def diseño_filtro_pasabanda(fs,fc,Q,order=4):
  w0=fc/(fs/2)
  bw= fc / Q
  fs0=fc-bw/2
  fsc=fc+bw/2
  wn=[fs0/(fs/2),fsc/(fs/2)]
  b, a= signal.butter(order,wn,btype='bandpass')
  return b,a

## aplicar filtro
def aplicar_filtro(x,fs,fc,Q,order=4):
  b,a=diseño_filtro_pasabanda(fs,fc,Q,order)
  y=signal.filtfilt(b,a,x)
  return y
def aplicar_hanning(y):
  ventana_tamaño=250
  ventana=signal.get_window('hamming',ventana_tamaño)
  num_ventanas = len(y) // ventana_tamaño
  y_hann = np.zeros_like(y)

  for i in range(num_ventanas):
    inicio = i * ventana_tamaño
    fin = (i + 1) * ventana_tamaño
    y_hann[inicio:fin] = y[inicio:fin] * ventana

  return y_hann, num_ventanas
##importacion de la señal
x, y=np.loadtxt('PruebaJose1.txt',skiprows=1, unpack=True,delimiter=',')
print(x)
print(y)
plt.plot(x,y, color='#6833ff')
plt.xlabel('tiempo(s)')
plt.ylabel('Voltaje(mV)')
plt.title('Electromiograma sin filtrar')
plt.show()
#aplicacion del filtro
fs=250
fc=10
Q=1
y=aplicar_filtro(y,fs,fc,Q)
plt.plot(x,y, color='#6833ff')
plt.xlabel('tiempo(s)')
plt.ylabel('Voltaje(mV)')
plt.title('Electromiograma filtrado')
plt.show()
#aplicacion de la ventana
y, num_windows =aplicar_hanning(y)
plt.plot(x,y, color='orange')
plt.xlabel('tiempo(s)')
plt.ylabel('Voltaje(mV)')
plt.title('Electromiograma filtrado y hanning')
plt.show()
# Calcula la Transformada Rápida de Fourier (FFT) de la señal con la ventana de Hanning
for i in range(num_windows):
  ventana_tamaño = 250
  inicio = i * ventana_tamaño
  fin = (i + 1) * ventana_tamaño
  v_ventana = y[inicio:fin]
  #Ventana hanning
  ventana_hanning = np.hanning(len(v_ventana))
  y_ventana_hanning = v_ventana * ventana_hanning

  fft_ventana = np.fft.fft(y_ventana_hanning)
  potencia_ventana = np.abs(fft_ventana[:len(v_ventana)//2])**2
  frecuencia_ventana = np.fft.fftfreq(len(v_ventana), d=1/100)[:len(v_ventana)//2]
  plt.plot(frecuencia_ventana, potencia_ventana, label=f'Ventana {i+1}', color='purple')

  #media de cada ventana
  media_ventana = np.mean(v_ventana)
  print(f'Media de la ventana {i+1}: {media_ventana}')
 #pueba de hipotesis
  if i > 0:  # Evitar comparar la primera ventana consigo misma
    t_stat, p_value = stats.ttest_ind(y[0:250], media_ventana)  # Comparar con la primera ventana
    print(f'Ventana {i+1} vs Ventana 1:')
    print(f'  T-statistic: {t_stat}')
    print(f'  P-value: {p_value}')


  #desviacion estandar de cada ventana
  std_ventana = np.std(v_ventana)
  print(f'Desviación estandar de la ventana {i+1}: {std_ventana}')

  plt.title(f'Frecuencias EMG (FFT) - Ventana {i+1}')
  plt.xlabel('Frecuencia Hz')
  plt.ylabel('Magnitud dB')
  plt.show()
# Out:
# [1.66694449e-03 3.33388898e-03 5.00083347e-03 ... 9.99666611e+00
#  9.99833306e+00 1.00000000e+01]
# [-1.78914529e+00 -1.49713579e+01  3.51474960e+01 ... -1.42018839e+00
#   1.25500160e-02 -7.84179920e-01]
# Media de la ventana 1: 0.0008818034173225797
# Desviación estandar de la ventana 1: 1.2343408483726497
# Media de la ventana 2: 0.0005767677252633092
# Ventana 2 vs Ventana 1:
#   T-statistic: 0.00024613783157638095
#   P-value: 0.9998038075051521
# Desviación estandar de la ventana 2: 0.7256827630576018
# Media de la ventana 3: 0.0010859708214368418
# Ventana 3 vs Ventana 1:
#   T-statistic: -0.00016474571151987876
#   P-value: 0.9998686838502945
# Desviación estandar de la ventana 3: 1.3088770633150866
# Media de la ventana 4: -0.0014919495999769303
# Ventana 4 vs Ventana 1:
#   T-statistic: 0.0019154165744724233
#   P-value: 0.9984732532698666
# Desviación estandar de la ventana 4: 1.0770311727830197
# Media de la ventana 5: 4.1217436985807154e-05
# Ventana 5 vs Ventana 1:
#   T-statistic: 0.000678281315398978
#   P-value: 0.9994593529416873
# Desviación estandar de la ventana 5: 0.4203795867264747
# Media de la ventana 6: -0.004901371779003924
# Ventana 6 vs Ventana 1:
#   T-statistic: 0.004666529981591561
#   P-value: 0.9962803977487499
# Desviación estandar de la ventana 6: 0.7625436097579023
# Media de la ventana 7: 0.007582228043008847
# Ventana 7 vs Ventana 1:
#   T-statistic: -0.005406672172930326
#   P-value: 0.9956904498683704
# Desviación estandar de la ventana 7: 1.2606213835577817
# Media de la ventana 8: 0.0002791613524529697
# Ventana 8 vs Ventana 1:
#   T-statistic: 0.00048628083507977287
#   P-value: 0.9996123934024603
# Desviación estandar de la ventana 8: 0.7840025292201741
# Media de la ventana 9: 0.007344614249095972
# Ventana 9 vs Ventana 1:
#   T-statistic: -0.005214938072597608
#   P-value: 0.9958432758641282
# Desviación estandar de la ventana 9: 1.2570094583390803
# Media de la ventana 10: -0.0079849873216357
# Ventana 10 vs Ventana 1:
#   T-statistic: 0.00715474517357353
#   P-value: 0.9942971168357543
# Desviación estandar de la ventana 10: 0.7747159524477049
# Media de la ventana 11: -0.0028928921542830536
# Ventana 11 vs Ventana 1:
#   T-statistic: 0.0030458579341444696
#   P-value: 0.9975721995208977
# Desviación estandar de la ventana 11: 0.6859320691727658
# Media de la ventana 12: 0.0014759558297806556
# Ventana 12 vs Ventana 1:
#   T-statistic: -0.00047943040842541863
#   P-value: 0.9996178537664515
# Desviación estandar de la ventana 12: 0.753757784450664
# Media de la ventana 13: 4.470618911128277e-05
# Ventana 13 vs Ventana 1:
#   T-statistic: 0.0006754661894795324
#   P-value: 0.9994615968326507
# Desviación estandar de la ventana 13: 0.7872819827500753
# Media de la ventana 14: -0.0011218733771146106
# Ventana 14 vs Ventana 1:
#   T-statistic: 0.001616796572339658
#   P-value: 0.99871127808504
# Desviación estandar de la ventana 14: 1.3637301567010522
# Media de la ventana 15: 0.0008338086492636876
# Ventana 15 vs Ventana 1:
#   T-statistic: 3.872769136384091e-05
#   P-value: 0.9999691307816647
# Desviación estandar de la ventana 15: 1.9317267866956762
# Media de la ventana 16: 6.884026743094296e-05
# Ventana 16 vs Ventana 1:
#   T-statistic: 0.0006559920431440883
#   P-value: 0.9994771193572408
# Desviación estandar de la ventana 16: 1.021990929841669
# Media de la ventana 17: 0.00020264681934020602
# Ventana 17 vs Ventana 1:
#   T-statistic: 0.0005480215485592808
#   P-value: 0.9995631808818647
# Desviación estandar de la ventana 17: 1.056433935421676
# Media de la ventana 18: -0.002540697082248158
# Ventana 18 vs Ventana 1:
#   T-statistic: 0.002761666498259281
#   P-value: 0.9977987229725481
# Desviación estandar de la ventana 18: 1.0577915650024845
# Media de la ventana 19: 0.0035195169998325044
# Ventana 19 vs Ventana 1:
#   T-statistic: -0.0021284102759765184
#   P-value: 0.9983034797734409
# Desviación estandar de la ventana 19: 1.4390221963174417
# Media de la ventana 20: -0.0004145515093960839
# Ventana 20 vs Ventana 1:
#   T-statistic: 0.0010460480492030103
#   P-value: 0.9991662121190683
# Desviación estandar de la ventana 20: 1.4181890428925514
# Media de la ventana 21: -0.0015406931373368807
# Ventana 21 vs Ventana 1:
#   T-statistic: 0.0019547484589091117
#   P-value: 0.9984419025179022
# Desviación estandar de la ventana 21: 1.6978933247304526
# Media de la ventana 22: 0.000907778134284527
# Ventana 22 vs Ventana 1:
#   T-statistic: -2.0959385000695828e-05
#   P-value: 0.9999832936121651
# Desviación estandar de la ventana 22: 0.5625636756445354
# Media de la ventana 23: 0.0018524357978587664
# Ventana 23 vs Ventana 1:
#   T-statistic: -0.0007832176877077582
#   P-value: 0.9993757098737689
# Desviación estandar de la ventana 23: 0.44483809918530526
